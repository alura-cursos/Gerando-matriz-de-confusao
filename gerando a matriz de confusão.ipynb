# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

"""
Infectados por covid-19?

0 -> Não infectado
1 -> Infectado
"""

valores_preditos = [1, 0, 0, 0, 1, 1, 0, 1, 1, 0]
valores_reais = [1, 0, 1, 0, 1, 1, 0, 1, 0, 1]

cm = confusion_matrix(valores_reais, valores_preditos)

groups_names = ['True Neg (TN)','False Pos (FP)','False Neg (FN)','True Pos (TP)']
group_counts = [f"{value}" for value in cm.flatten()]
labels = [f"{v1}" for v1 in groups_names]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(groups_names, group_counts)]

labels = np.asarray(labels).reshape(cm.shape)

ax = plt.subplot()
sns.set(font_scale=1.4) 
sns.heatmap(cm, annot=labels, ax=ax, cmap="viridis", fmt="")

label_font = {'size':'14'}  
ax.set_xlabel('Valores previstos', fontdict=label_font);
ax.set_ylabel('Valores reais', fontdict=label_font);

ax.tick_params(axis='both', which='major', labelsize=10)  
ax.xaxis.set_ticklabels(['Não infectado', 'Infectado']);
ax.yaxis.set_ticklabels(['Não infectado', 'Infectado']);

# %%
from sklearn.metrics import classification_report
y_true = [1, 0, 1, 0, 1, 1, 0, 1, 0, 1]
y_pred = [1, 0, 0, 0, 1, 1, 0, 1, 1, 0]
target_names = ['não infectado', 'infectado']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#                precision    recall  f1-score   support
#
# não infectado       0.60      0.75      0.67         4
#     infectado       0.80      0.67      0.73         6
#
#      accuracy                           0.70        10
#     macro avg       0.70      0.71      0.70        10
#  weighted avg       0.72      0.70      0.70        10
